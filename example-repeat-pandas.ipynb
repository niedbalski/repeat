# %%
import repeat_pandas

# %%
data = repeat_pandas.load_collection("./repeat-report-2020-07-06-18-15.tar.gz", "process_list")

# %%
data.groupby("created_at")["rss"].agg("sum").plot()

# %%
data.groupby("created_at")["rss"].agg("sum")
# Out:
# created_at
# 2020-07-06 22:13:37     226028
# 2020-07-06 22:13:38    1486484
# 2020-07-06 22:13:39    2129968
# 2020-07-06 22:13:40     530660
# 2020-07-06 22:13:41    6525848
#                         ...
# 2020-07-06 22:15:01    8124656
# 2020-07-06 22:15:02    5830732
# 2020-07-06 22:15:03    1168192
# 2020-07-06 22:15:04    1498152
# 2020-07-06 22:15:05     481696
# Name: rss, Length: 89, dtype: int64
