# %%
import repeat_pandas

# %%
collections = repeat_pandas.load("./repeat-report-2020-07-16-23-06.tar.gz")

# %%
collections.lxc_containers_memory_bytes.groupby("created_at")["bytes"].agg("sum").plot()

# %%
collections.lxc_containers_memory_bytes.groupby("created_at")["bytes"].agg("sum")
# Out:
# created_at
# 2020-07-17 03:05:31      430940160
# 2020-07-17 03:05:32      430940160
# 2020-07-17 03:05:33      861847552
# 2020-07-17 03:05:34      430940160
# 2020-07-17 03:05:35      430940160
# 2020-07-17 03:05:36      430940160
# 2020-07-17 03:05:37      430940160
# 2020-07-17 03:05:38      430940160
# 2020-07-17 03:05:39      430940160
# 2020-07-17 03:05:40      430940160
# 2020-07-17 03:05:41      430940160
# 2020-07-17 03:05:42      432111616
# 2020-07-17 03:05:43      350904320
# 2020-07-17 03:05:48     5209935872
# 2020-07-17 03:05:49    10435743744
# 2020-07-17 03:05:50     1585590272
# 2020-07-17 03:05:51      255807488
# 2020-07-17 03:05:53     2266820608
# 2020-07-17 03:05:56     2734833664
# 2020-07-17 03:05:58    17378947072
# 2020-07-17 03:05:59     1927565312
# 2020-07-17 03:06:01     3855130624
# 2020-07-17 03:06:02     1927565312
# 2020-07-17 03:06:03     1927565312
# 2020-07-17 03:06:04     1927565312
# 2020-07-17 03:06:05     1927565312
# ...
